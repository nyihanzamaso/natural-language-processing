# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

sentences=['Today is a sunny day',
           'Today is a rainy day',
           'is it sunny today?'
           ]
tokenizer=Tokenizer(num_words=100)
tokenizer.fit_on_texts(sentences)
word_index=tokenizer.word_index
print(word_index)
# Out:
# {'today': 1, 'is': 2, 'a': 3, 'sunny': 4, 'day': 5, 'rainy': 6, 'it': 7}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sentences=['Today is a sunny day',
           'Today is a rainy day',
           'is it sunny today?'
           ]
tokenizer=Tokenizer(num_words=100, oov_token='<00V>')
tokenizer.fit_on_texts(sentences)
word_index=tokenizer.word_index

sequences=tokenizer.texts_to_sequences(sentences)
print(sequences)
# Out:
# [[2, 3, 4, 5, 6], [2, 3, 4, 7, 6], [3, 8, 5, 2]]

# %%
test_sentences=['Today is a swony day',
                'will it  be rainy tomorrow?'
           ]
test_sequences=tokenizer.texts_to_sequences(test_sentences)
word_index=tokenizer.word_index
print(test_sequences)
print(word_index)
# Out:
# [[2, 3, 4, 1, 6], [1, 8, 1, 7, 1]]
# {'<00V>': 1, 'today': 2, 'is': 3, 'a': 4, 'sunny': 5, 'day': 6, 'rainy': 7, 'it': 8}

# %%
sentences=['Today is a sunny day',
           'Today is a rainy day',
           'is it sunny today?',
           'I really enjoyed walking in the snow today'
           ]
tokenizer=Tokenizer(num_words=100, oov_token='<00V>')
tokenizer.fit_on_texts(sentences)
word_index=tokenizer.word_index

sequences=tokenizer.texts_to_sequences(sentences)
print(sequences)
print(word_index)
# Out:
# [[2, 3, 4, 5, 6], [2, 3, 4, 7, 6], [3, 8, 5, 2], [9, 10, 11, 12, 13, 14, 15, 2]]
# {'<00V>': 1, 'today': 2, 'is': 3, 'a': 4, 'sunny': 5, 'day': 6, 'rainy': 7, 'it': 8, 'i': 9, 'really': 10, 'enjoyed': 11, 'walking': 12, 'in': 13, 'the': 14, 'snow': 15}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded=pad_sequences(sequences)
print(padded)
# Out:
# [[ 0  0  0  2  3  4  5  6]
#  [ 0  0  0  2  3  4  7  6]
#  [ 0  0  0  0  3  8  5  2]
#  [ 9 10 11 12 13 14 15  2]]

# %%
padded=pad_sequences(sequences, padding='post')
print(padded)
# Out:
# [[ 2  3  4  5  6  0  0  0]
#  [ 2  3  4  7  6  0  0  0]
#  [ 3  8  5  2  0  0  0  0]
#  [ 9 10 11 12 13 14 15  2]]

# %%
padded=pad_sequences(sequences, padding='post', maxlen=6)
print(padded)
# Out:
# [[ 2  3  4  5  6  0]
#  [ 2  3  4  7  6  0]
#  [ 3  8  5  2  0  0]
#  [11 12 13 14 15  2]]

# %%
padded=pad_sequences(sequences, padding='post', maxlen=6, truncating='post')
print(padded)
# Out:
# [[ 2  3  4  5  6  0]
#  [ 2  3  4  7  6  0]
#  [ 3  8  5  2  0  0]
#  [ 9 10 11 12 13 14]]

# %%
import tensorflow_datasets as tfds
imdb_sentences=[]
train_data=tfds.as_numpy(tfds.load('imdb_reviews', split='train'))
for item in train_data:
  imdb_sentences.append(str(item['text']))
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.6DJ3PE_1.0.0/imdb_reviews-train.tfrecor…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.6DJ3PE_1.0.0/imdb_reviews-test.tfrecord…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.6DJ3PE_1.0.0/imdb_reviews-unsupervised.…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
imdb_sentences[0]
# Out:
# 'b"This was an absolutely terrible movie. Don\'t be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie\'s ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining act
': 222, 'script': 223, 'guy': 224, 'far': 225, 'xc2': 226, 'anything': 227, 'making': 228, 'minutes': 229, 'feel': 230, 'last': 231, 'might': 232, 'performance': 233, 'since': 234, '2': 235, 'probably': 236, 'girl': 237, 'kind': 238, 'am': 239, 'away': 240, 'tv': 241, 'yet': 242, 'woman': 243, 'rather': 244, 'day': 245, "'ve": 246, 'worst': 247, 'fun': 248, 'sure': 249, 'hard': 250, "'m": 251, 'doesn': 252, 'anyone': 253, 'played': 254, "b'i": 255, 'each': 256, 'found': 257, 'xc3': 258, 'especially': 259, 'course': 260, 'our': 261, 'having': 262, 'believe': 263, 'comes': 264, 'screen': 265, 'looking': 266, 'although': 267, 'trying': 268, 'goes': 269, 'set': 270, 'looks': 271, 'place': 272, 'book': 273, 'different': 274, 'put': 275, 'money': 276, 'actor': 277, 'ending': 278, 'maybe': 279, 'year': 280, 'sense': 281, 'reason': 282, 'true': 283, 'everything': 284, 'dvd': 285, 'shows': 286, 'once': 287, 'didn': 288, 'someone': 289, 'three': 290, 'worth': 291, 'job': 292, "'re": 293, 'main': 294, 'together': 295, 'play': 296, 'watched': 297, 'american': 298, 'plays': 299, '1': 300, 'effects': 301, 'later': 302, 'said': 303, 'takes': 304, 'instead': 305, 'audience': 306, 'seem': 30 ...

# %%
from bs4 import BeautifulSoup
import string

stopwords=[
    "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "aren't", "as", "at", "be", "because"," been", "before", "being",
     "below", "between", "both", "but", "by", "can't", "cannot", "could", "couldn't"," did", "didn't", "do", "does", "doesn't", "doing", "don't", "down",
      "during", "each", "few", "for", "from", "further", "had", "hadn't", "has", "hasn't", "have", "haven't", "having", "he", "he'd", "he'll", "he's", "her",
     "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "isn't", "it", "it's",
     "its", "itself", "let's", "me", "more", "most", "mustn't", "my", "myself", "no", "nor", "not", "of", "off", "on", "once", "only", "or", "other", "ought", "our",
    "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "shouldn't", "so", "some", "such", "than", "that", "that's",
     "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those",
      "through", "to", "too", "under", "until", "up", "very", "was", "wasn't", "we", "we'd", "we'll", "we're", "we've", "were", "weren't", "what", "what's", "when",
       "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "won't", "would", "wouldn't", "you", "you'd", "you'll",
     "you're", "you've", "your", "yours", "yourself", "yourselves"

]
table=str.maketrans(" "," ",string.punctuation)

imdb_sentences=[]
train_data=tfds.as_numpy(tfds.load('imdb_reviews',split='train'))
for item in train_data:
  sentence=str(item['text'].decode('UTF-8').lower())
  soup=BeautifulSoup(sentence)
  sentence=soup.get_text()
  words=sentence.split()
  filtered_sentence=''
  for word in words:
    word=word.translate(table)
    if word not in stopwords:
      filtered_sentence=filtered_sentence+ word + " "
  imdb_sentences.append(filtered_sentence)

tokenizer=Tokenizer(num_words=25000)
tokenizer.fit_on_texts(imdb_sentences)
sequences=tokenizer.texts_to_sequences(imdb_sentences)
print(tokenizer.word_index)

# %%
sentence=sentence.replace(',',' , ')
sentence=sentence.replace('.',' . ')
sentence=sentence.replace('-',' - ')
sentence=sentence.replace('/',' / ')

# %%
sentences=[
    'Today is a sunny day',
    'Today is a rainy day',
    'Is it sunny today?'
]
sequences=tokenizer.texts_to_sequences(sentences)
print(sequences)
# Out:
# [[535, 5124, 162], [535, 6313, 162], [5124, 535]]

# %%
reverse_word_index=dict(
    [(value, key) for (key, value) in tokenizer.word_index.items()]
)
decode_review=' '.join([reverse_word_index.get(i,'?') for i in sequences[0]])
print(decode_review)
# Out:
# today sunny day

# %%
(train_data, test_data), info=tfds.load('imdb_reviews/subwords8k',
                                  split=(tfds.Split.TRAIN, tfds.Split.TEST),
                                  as_supervised=True,
                                  with_info=True
                                  )
encoder=info.features['text'].encoder
print('Vocaburaly size: {}'.format(encoder.vocab_size))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7ff853cf20b6> in <cell line: 1>()
# ----> 1 (train_data, test_data), info=tfds.load('imdb_reviews/subwords8k',
#       2                                   split=(tfds.Split.TRAIN, tfds.Split.TEST),
#       3                                   as_supervised=True,
#       4                                   with_info=True
#       5                                   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     653       Split-specific information is available in `ds_info.splits`.
#     654   """  # fmt: skip
# --> 655   dbuilder = _fetch_builder(
#     656       name,
#     657       data_dir,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in _fetch_builder(name, data_dir, builder_kwargs, try_gcs)
#     495   if builder_kwargs is None:
#     496     builder_kwargs = {}
# --> 497   return builder(name, data_dir=data_dir, try_gcs=try_gcs, **builder_kwargs)
#     498
#     499
#
# /usr/lib/python3.10/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
#     178       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/load.py in builder(name, try_gcs, **builder_kwargs)
#     219         prefix=f'Failed to construct {get_dataset_repr()}: '
#     220     ):
# --> 221       return cls(**builder_kwargs)  # pytype: disable=not-instantiable
#     222
#     223   # If neither the code nor the files are found, raise DatasetNotFoundError
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in decorator(function, dsbuilder, args, kwargs)
#     294     _thread_id_to_builder_init_count[metadata.thread_id] += 1
#     295     try:
# --> 296       return function(*args, **kwargs)
#     297     except Exception:
#     298       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in __init__(self, file_format, **kwargs)
#    1464       **kwargs: Arguments passed to `DatasetBuilder`.
#    1465     """
# -> 1466     super().__init__(**kwargs)
#    1467     self.info.set_file_format(file_format)
#    1468
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/logging/__init__.py in decorator(function, dsbuilder, args, kwargs)
#     294     _thread_id_to_builder_init_count[metadata.thread_id] += 1
#     295     try:
# --> 296       return function(*args, **kwargs)
#     297     except Exception:
#     298       metadata.mark_error()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in __init__(self, data_dir, config, version)
#     285     )
#     286     # To do the work:
# --> 287     self._builder_config = self._create_builder_config(config, version=version)
#     288     # Extract code version (VERSION or config)
#     289     self._version = self._pick_version(version)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow_datasets/core/dataset_builder.py in _create_builder_config(self, builder_config, version)
#    1360         builder_config = self.builder_configs.get(f"{name}:{version}")
#    1361       if builder_config is None:
# -> 1362         raise ValueError(
#    1363             "BuilderConfig %s not found with version %s. Available: %s"
#    1364             % (name, version, list(self.builder_configs.keys()))
#
# ValueError: Failed to construct dataset "imdb_reviews", builder_kwargs "{'config': 'subwords8k', 'data_dir': None}": BuilderConfig subwords8k not found with version None. Available: ['plain_text']

# %%
print(encoder.subwords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-852f1488cfab> in <cell line: 1>()
# ----> 1 print(encoder.subwords)
#
# NameError: name 'encoder' is not defined

# %%
sample_String='Today is a sunny day'
encoded_string=encoder.encode(sample_String)
print(f'Encoded string: {encoded_string}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-94639f655271> in <cell line: 2>()
#       1 sample_String='Today is a sunny day'
# ----> 2 encoded_string=encoder.encode(sample_String)
#       3 print(f'Encoded string: {encoded_string}')
#
# NameError: name 'encoder' is not defined

# %%
print(encoder.subwords[4869])

# %%
import csv
sentences=[]
labels=[]
with open('/content/drive/MyDrive/archive (10)/train.csv', encoding='UTF-8') as csvfile:
  reader=csv.reader(csvfile, delimiter=',')
  for row in reader:
    labels.append(int(row[1]))
    sentence=row[0].lower()
    sentence=sentence.replace(',',' , ')
    sentence=sentence.replace('.',' . ')
    sentence=sentence.replace('-',' - ')
    sentence=sentence.replace('/',' / ')
    soup=BeautifulSoup(sentence)
    sentence=soup.get_text()
    words=sentence.split()
    filtered_sentence=""
    for word in words:
      word=word.translate(table)
      if word not in stopwords:
        filtered_sentence=filtered_sentence + word + " "
    sentences.append(filtered_sentence)

print(sentences[0])
# Out:
# <ipython-input-21-9dc7cbf5bcc3>:13: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup=BeautifulSoup(sentence)
# rented curious  yellow video store controversy surrounded first released 1967  also heard first seized u  s  customs ever tried enter country  therefore fan films considered controversial really see  plot centered around young swedish drama student named lena wants learn everything can life  particular wants focus attentions making sort documentary average swede thought certain political issues vietnam war race issues united states  asking politicians ordinary denizens stockholm opinions politics  sex drama teacher  classmates  married men  kills curious  yellow 40 years ago  considered pornographic  really  sex nudity scenes far  even shot like cheaply made porno  countrymen mind find shocking  reality sex nudity major staple swedish cinema  even ingmar bergman  arguably answer good old boy john ford  sex scenes films  commend filmmakers fact sex shown film shown artistic purposes rather just shock people make money shown pornographic theaters america  curious  yellow good film anyone wanting study meat potatoes pun intended swedish cinema  really  film doesnt much plot

# %%
training_size = 28000
training_sentences=sentences[0:training_size]
testing_sentences=sentences[training_size:]
training_labels=sentences[0:training_size]
testing_labels=sentences[training_size:]

# %%
vocab_size=20000
max_length=10
trunc_type='post'
padding_type='post'
oov_tok='<OOV>'

tokenizer=Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index=tokenizer.word_index
training_sequences=tokenizer.texts_to_sequences(training_sentences)
training_padded=pad_sequences(training_sequences, maxlen=max_length,
                              truncating=trunc_type,
                              padding=padding_type)

# %%
print(training_sequences[0])
print(training_padded[0])
# Out:
# [1491, 1879, 4000, 268, 1009, 6936, 3268, 22, 512, 6937, 20, 449, 22, 19208, 1100, 690, 8955, 47, 685, 2431, 589, 1506, 234, 29, 1071, 2976, 11, 12, 38, 3872, 95, 93, 3793, 345, 1347, 660, 4559, 383, 737, 185, 13, 37, 729, 383, 1023, 11756, 134, 323, 545, 739, 1, 104, 694, 874, 1216, 2485, 221, 1400, 1216, 2226, 1478, 2120, 6938, 1839, 18263, 1, 4560, 2302, 277, 345, 1632, 7905, 899, 243, 973, 1879, 4000, 1572, 61, 489, 1071, 7656, 11, 277, 895, 54, 133, 9, 219, 5, 6307, 25, 4339, 1, 226, 79, 1487, 513, 277, 895, 565, 9914, 3793, 330, 9, 14197, 4818, 4561, 1403, 7, 66, 320, 208, 1990, 277, 54, 29, 12450, 901, 99, 277, 505, 3, 505, 1484, 4819, 150, 6, 1323, 21, 28, 178, 505, 7656, 2106, 822, 1879, 4000, 7, 3, 160, 1669, 1954, 3402, 17412, 5109, 1316, 3793, 330, 11, 3, 63, 15, 38]
# [1491 1879 4000  268 1009 6936 3268   22  512 6937]

# %%
print(word_index)
# Out:
': 235, 'poor': 236, 'completely': 237, 'help': 238, 'used': 239, 'home': 240, 'dead': 241, 'either': 242, 'men': 243, 'short': 244, 'line': 245, 'friends': 246, 'top': 247, '3': 248, 'given': 249, 'budget': 250, 'try': 251, 'classic': 252, 'performances': 253, 'wrong': 254, 'boring': 255, 'hollywood': 256, 'enjoy': 257, 'rest': 258, 'need': 259, 'use': 260, 'low': 261, 'production': 262, 'full': 263, 'along': 264, 'camera': 265, 'truly': 266, 'women': 267, 'video': 268, 'tell': 269, 'awful': 270, 'next': 271, 'couple': 272, 'stars': 273, 'stupid': 274, 'remember': 275, 'start': 276, 'sex': 277, 'mean': 278, 'perhaps': 279, 'came': 280, 'others': 281, 'recommend': 282, 'let': 283, 'moments': 284, 'wonderful': 285, 'understand': 286, 'face': 287, 'episode': 288, 'small': 289, 'playing': 290, 'terrible': 291, 'school': 292, 'gettin ...

# %%
import json
with open('/content/drive/MyDrive/Sarcasm_Headlines_Dataset.json (1)/Sarcasm_Headlines_Dataset.json','r') as f:
  datastore=[]
  for line in f:
    datastore.append(json.loads(line))
  for item in datastore:
    sentence=item['headline'].lower()
    label=item['is_sarcastic']
    link=item['article_link']

# %%
sentences=[]
labels=[]
urls=[]
for item in datastore:
  sentence=item['headline'].lower()
  sentence=sentence.replace(',',' , ')
  sentence=sentence.replace('.',' . ')
  sentence=sentence.replace('-',' - ')
  sentence=sentence.replace('/',' / ')
  soup=BeautifulSoup(sentence)
  sentence=soup.get_text()
  word=sentence.split()
  filtered_sentence=''
  for word in words:
    word= word.translate(table)
    if word not in stopwords:
      filtered_sentence=filtered_sentence + word + " "
  sentences.append(filtered_sentence)
  labels.append(item['is_sarcastic'])
  urls.append(item['article_link'])
# Out:
# <ipython-input-27-843dc2321bf2>:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup=BeautifulSoup(sentence)

# %%
training_size= 23000
training_sentences=sentences[0:training_size]
testing_sentences=sentences[training_size:]
training_labels=labels[0:training_size]
testing_labels=labels[training_size:]

# %%
vocab_size=20000
max_length=10
trunc_type='post'
oov_token='<OOV>'
tokenizer=Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index=tokenizer.word_index
training_sequences=tokenizer.texts_to_sequences(training_sentences)
training_padded=pad_sequences(training_sequences, padding='post')
tokenizer.fit_on_texts(testing_sentences)
testing_sequences=tokenizer.texts_to_sequences(testing_sentences)
testing_padded=pad_sequences(testing_sequences, padding='post')
print(word_index)
# Out:
# {'<OOV>': 1, 'barry': 2, 'story': 3, 'centers': 4, 'around': 5, 'mckenzie': 6, 'must': 7, 'go': 8, 'england': 9, 'wishes': 10, 'claim': 11, 'inheritance': 12, 'grossest': 13, 'aussie': 14, 'shearer': 15, 'ever': 16, 'set': 17, 'foot': 18, 'outside': 19, 'great': 20, 'nation': 21, 'something': 22, 'culture': 23, 'clash': 24, 'much': 25, 'fun': 26, 'games': 27, 'ensue': 28, 'songs': 29, 'mckenziebarry': 30, 'crocker': 31, 'highlights': 32}

# %%
import numpy as np
training_padded=np.array(training_padded)
training_labels=np.array(training_labels)
testing_padded=np.array(testing_padded)
testing_labels=np.array(testing_labels)

# %%
import tensorflow as tf
model=tf.keras.Sequential([
    tf.keras.layers.Conv2D(64,3, activation='relu'),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
